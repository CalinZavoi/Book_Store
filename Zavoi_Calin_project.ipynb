# %% [markdown]
# <a href="https://colab.research.google.com/github/CalinZavoi/Book_Store/blob/main/Zavoi_Calin_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3


conn = sqlite3.connect(':memory:') 

with open('BX-Book-Ratings.sql', 'r') as file:
    sql_script = file.read()
    cursor = conn.cursor()
    cursor.executescript(sql_script)


query = "SELECT * FROM BX-Book-Ratings;"  
df = pd.read_sql_query(query, conn)


conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-13-6605a07414a7> in <cell line: 7>()
#       8     sql_script = file.read()
#       9     cursor = conn.cursor()
# ---> 10     cursor.executescript(sql_script)
#      11
#      12
#
# OperationalError: unrecognized token: "'03"

# %%
import pandas as pd

path = 'BX-'
l_path = ['Book-Ratings',
          'Books',
          'Users'
]

dataframes = {}


def replace_characters(df):
    df.replace('%amp;', '&', regex=True, inplace=True)
    df.replace('EOF', '', regex=True, inplace=True)


for crt in l_path:
    final_path = path + crt + '.csv'
    dataframes[crt] = pd.read_csv(final_path, sep=';', encoding='latin-1', on_bad_lines = 'warn', dtype=object)
    replace_characters(dataframes[crt])


ratings_df = dataframes['Book-Ratings']
books_df = dataframes['Books']
users_df = dataframes['Users']

display(ratings_df)
display(books_df)
display(users_df)
# Out:
# Skipping line 6452: expected 8 fields, saw 9
# Skipping line 43667: expected 8 fields, saw 10
# Skipping line 51751: expected 8 fields, saw 9
#
# Skipping line 92038: expected 8 fields, saw 9
# Skipping line 104319: expected 8 fields, saw 9
# Skipping line 121768: expected 8 fields, saw 9
#
# Skipping line 144058: expected 8 fields, saw 9
# Skipping line 150789: expected 8 fields, saw 9
# Skipping line 157128: expected 8 fields, saw 9
# Skipping line 180189: expected 8 fields, saw 9
# Skipping line 185738: expected 8 fields, saw 9
#
# Skipping line 209388: expected 8 fields, saw 9
# Skipping line 220626: expected 8 fields, saw 9
# Skipping line 227933: expected 8 fields, saw 11
# Skipping line 228957: expected 8 fields, saw 10
# Skipping line 245933: expected 8 fields, saw 9
# Skipping line 251296: expected 8 fields, saw 9
# Skipping line 259941: expected 8 fields, saw 9
# Skipping line 261529: expected 8 fields, saw 9
#         User-ID         ISBN Book-Rating
# 0        276725   034545104X           0
# 1        276726   0155061224           5
# 2        276727   0446520802           0
# 3        276729   052165615X           3
# 4        276729   0521795028           6
# ...         ...          ...         ...
# 1149775  276704   1563526298           9
# 1149776  276706   0679447156           0
# 1149777  276709   0515107662          10
# 1149778  276721   0590442449          10
# 1149779  276723  05162443314           8
#
# [1149780 rows x 3 columns]
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271355        Paula Danziger                1988
# 271356            Teri Sloat                1991
# 271357      Christine Wicker                2004
# 271358                 Plato                1996
# 271359   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [271360 rows x 8 columns]
#        User-ID                            Location  Age
# 0            1                  nyc, new york, usa  NaN
# 1            2           stockton, california, usa   18
# 2            3     moscow, yukon territory, russia  NaN
# 3            4           porto, v.n.gaia, portugal   17
# 4            5  farnborough, hants, united kingdom  NaN
# ...        ...                                 ...  ...
# 167680  167681             new york, new york, usa   31
# 167681  167682                 mcallen, texas, usa  NaN
# 167682  167683         alamogordo, new mexico, usa  NaN
# 167683  167684       providence, rhode island, usa   24
# 167684  167685             bloomer, wisconsin, usa   30
#
# [167685 rows x 3 columns]

# %%
ratings = ratings_df
books = books_df
users = users_df


display(ratings)
display(books)
display(users)
# Out:
#         User-ID         ISBN Book-Rating
# 0        276725   034545104X           0
# 1        276726   0155061224           5
# 2        276727   0446520802           0
# 3        276729   052165615X           3
# 4        276729   0521795028           6
# ...         ...          ...         ...
# 1149775  276704   1563526298           9
# 1149776  276706   0679447156           0
# 1149777  276709   0515107662          10
# 1149778  276721   0590442449          10
# 1149779  276723  05162443314           8
#
# [1149780 rows x 3 columns]
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271355        Paula Danziger                1988
# 271356            Teri Sloat                1991
# 271357      Christine Wicker                2004
# 271358                 Plato                1996
# 271359   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271355  http://images.amazon.com/images/P/0440400988.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [271360 rows x 8 columns]
#        User-ID                            Location  Age
# 0            1                  nyc, new york, usa  NaN
# 1            2           stockton, california, usa   18
# 2            3     moscow, yukon territory, russia  NaN
# 3            4           porto, v.n.gaia, portugal   17
# 4            5  farnborough, hants, united kingdom  NaN
# ...        ...                                 ...  ...
# 167680  167681             new york, new york, usa   31
# 167681  167682                 mcallen, texas, usa  NaN
# 167682  167683         alamogordo, new mexico, usa  NaN
# 167683  167684       providence, rhode island, usa   24
# 167684  167685             bloomer, wisconsin, usa   30
#
# [167685 rows x 3 columns]

# %% [markdown]
# I want to make 2 merges: ratings with books and ratings with users

# %%
def merge_unique_col(left_df, right_df, left_index, right_index):

  merged_df = left_df.merge(right_df, left_on=left_index, right_on = right_index, suffixes=('', '_remove'))

  merged_df.drop(
              [i for i in merged_df.columns if 'remove' in i],
               axis=1, inplace=True
               )

  return merged_df

ratings_books = merge_unique_col(ratings, books, 'ISBN', 'ISBN')

display(ratings_books)

ratings_users = merge_unique_col(ratings, users, 'User-ID', 'User-ID')

display(ratings_users)
# Out:
#         User-ID        ISBN Book-Rating  \
# 0        276725  034545104X           0
# 1          2313  034545104X           5
# 2          6543  034545104X           0
# 3          8680  034545104X           5
# 4         10314  034545104X           9
# ...         ...         ...         ...
# 1031131  276688  0517145553           0
# 1031132  276688  1575660792           7
# 1031133  276690  0590907301           0
# 1031134  276704  0679752714           0
# 1031135  276704  0806917695           5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# 4                                     Flesh Tones: A Novel       M. J. Rose
# ...                                                    ...              ...
# 1031131                                    Mostly Harmless    Douglas Adams
# 1031132                                        Gray Matter  Shirley Kennett
# 1031133  Triplet Trouble and the Class Trip (Triplet Tr...     Debbie Dadey
# 1031134  A Desert of Pure Feeling (Vintage Contemporaries)   Judith Freeman
# 1031135  Perplexing Lateral Thinking Puzzles: Scholasti...      Paul Sloane
#
#         Year-Of-Publication                          Publisher  \
# 0                      2002                   Ballantine Books
# 1                      2002                   Ballantine Books
# 2                      2002                   Ballantine Books
# 3                      2002                   Ballantine Books
# 4                      2002                   Ballantine Books
# ...                     ...                                ...
# 1031131                1995             Random House Value Pub
# 1031132                1996  Kensington Publishing Corporation
# 1031133                1997                              Apple
# 1031134                1997                  Vintage Books USA
# 1031135                1997                Sterling Publishing
#
#                                                Image-URL-S  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/034545104X.0...
# 2        http://images.amazon.com/images/P/034545104X.0...
# 3        http://images.amazon.com/images/P/034545104X.0...
# 4        http://images.amazon.com/images/P/034545104X.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0517145553.0...
# 1031132  http://images.amazon.com/images/P/1575660792.0...
# 1031133  http://images.amazon.com/images/P/0590907301.0...
# 1031134  http://images.amazon.com/images/P/0679752714.0...
# 1031135  http://images.amazon.com/images/P/0806917695.0...
#
#                                                Image-URL-M  \
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/034545104X.0...
# 2        http://images.amazon.com/images/P/034545104X.0...
# 3        http://images.amazon.com/images/P/034545104X.0...
# 4        http://images.amazon.com/images/P/034545104X.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0517145553.0...
# 1031132  http://images.amazon.com/images/P/1575660792.0...
# 1031133  http://images.amazon.com/images/P/0590907301.0...
# 1031134  http://images.amazon.com/images/P/0679752714.0...
# 1031135  http://images.amazon.com/images/P/0806917695.0...
#
#                                                Image-URL-L
# 0        http://images.amazon.com/images/P/034545104X.0...
# 1        http://images.amazon.com/images/P/034545104X.0...
# 2        http://images.amazon.com/images/P/034545104X.0...
# 3        http://images.amazon.com/images/P/034545104X.0...
# 4        http://images.amazon.com/images/P/034545104X.0...
# ...                                                    ...
# 1031131  http://images.amazon.com/images/P/0517145553.0...
# 1031132  http://images.amazon.com/images/P/1575660792.0...
# 1031133  http://images.amazon.com/images/P/0590907301.0...
# 1031134  http://images.amazon.com/images/P/0679752714.0...
# 1031135  http://images.amazon.com/images/P/0806917695.0...
#
# [1031136 rows x 10 columns]
#        User-ID        ISBN Book-Rating                   Location  Age
# 0            2  0195153448           0  stockton, california, usa   18
# 1            7   034542252           0        washington, dc, usa  NaN
# 2            8  0002005018           5   timmins, ontario, canada  NaN
# 3            8  0060973129           0   timmins, ontario, canada  NaN
# 4            8  0374157065           0   timmins, ontario, canada  NaN
# ...        ...         ...         ...                        ...  ...
# 678610  167678  1551668653           8            belton, tx, usa   35
# 678611  167678  1561451010           0            belton, tx, usa   35
# 678612  167678  1575667215           0            belton, tx, usa   35
# 678613  167678  1575667223           0            belton, tx, usa   35
# 678614  167680  0446525731           0    rialto, california, usa  NaN
#
# [678615 rows x 5 columns]

# %% [markdown]
# I want to identify the book with the highest average rating

# %%
ratings_books['Book-Rating'] = ratings_books['Book-Rating'].astype(int)

# %%
average_ratings = ratings_books.groupby('ISBN')['Book-Rating'].mean()

highest_average_rating_isbn = average_ratings.nlargest(4)

print(highest_average_rating_isbn)
# Out:
# ISBN
# 0001360469    10.0
# 0001374869    10.0
# 0001821326    10.0
# 0001845039    10.0
# Name: Book-Rating, dtype: float64

# %%
highest_average_rating_books = ratings_books[ratings_books['ISBN'].isin(highest_average_rating_isbn.index)]

print(highest_average_rating_books['Book-Title'])
# Out:
# 424741                                        Babe Dressing
# 424742         Baby Plays (Collins Baby and Toddler Series)
# 767054                                  The Moon of Gomrath
# 981995    Paddington at the Tower (A Paddington Picture ...
# Name: Book-Title, dtype: object

# %% [markdown]
# Find the books with the highest average rating but who have atleast 100 ratings

# %% [markdown]
# Then, the book with the most 10 ratings

# %%
ratings_10 = ratings_books[ratings_books['Book-Rating'] == 10]

ratings_10_count = ratings_10.groupby('ISBN').size()

isbn_with_most_10_ratings = ratings_10_count.nlargest(4)

print(isbn_with_most_10_ratings)
# Out:
# ISBN
# 0385504209    158
# 059035342X    152
# 0316666343    148
# 043935806X    111
# dtype: int64

# %%
highest_10_ratings_books = ratings_books[ratings_books['ISBN'].isin(isbn_with_most_10_ratings.index)]

print(highest_10_ratings_books['Book-Title'].unique())
# Out:
# ['Harry Potter and the Order of the Phoenix (Book 5)'
#  'The Lovely Bones: A Novel' 'The Da Vinci Code'
#  "Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))"]

# %%
avg_ratings = ratings_books.groupby('ISBN')['Book-Rating'].mean()

rating_counts = ratings_books['ISBN'].value_counts()

filtered_books = average_ratings[rating_counts >= 100]

sorted_books = filtered_books.sort_values(ascending=False)

top_books = sorted_books.head(4)

print(top_books)
# Out:
# ISBN
# 0439064864    6.611765
# 0439139597    6.541237
# 0439136350    6.467005
# 0590353403    6.363095
# Name: Book-Rating, dtype: float64

# %%
top_avg_over_100 = ratings_books[ratings_books['ISBN'].isin(top_books.index)]

print(top_avg_over_100['Book-Title'].unique())
# Out:
# ['Harry Potter and the Chamber of Secrets (Book 2)'
#  'Harry Potter and the Prisoner of Azkaban (Book 3)'
#  'Harry Potter and the Goblet of Fire (Book 4)'
#  "Harry Potter and the Sorcerer's Stone (Book 1)"]

# %% [markdown]
# For the international aspect I want to see the 5 countries which gave the most reviews.
# First of all I need to normaliza the location column

# %%
location_split = ratings_users['Location'].str.split(',', n=2, expand=True)
ratings_users['City'] = location_split[0].str.strip()
ratings_users['State'] = location_split[1].str.strip()
ratings_users['Country'] = location_split[2].str.strip()

ratings_users = ratings_users.drop('Location', axis=1)


display(ratings_users)

# %%
nan_country_entries = ratings_users[ratings_users['Country'].notna()]

# display(nan_country_entries)

most_reviewed_country = ratings_users['Country'].value_counts().head(5)
print(most_reviewed_country)
# Out:
# usa               447544
# canada             56164
# united kingdom     29858
# germany            24177
# spain              16506
# Name: Country, dtype: int64

# %% [markdown]
# I want to know the authors of the titles who appears the most in the book titles obtained previously

# %%
l_books_avg = list(top_avg_over_100['Book-Title'].unique())

l_books_10 = list(highest_10_ratings_books['Book-Title'].unique())

l_best_books = l_books_avg + l_books_10

l_best_books = list(set(l_best_books))

# print(l_best_books)


best_auth = ratings_books[ratings_books['Book-Title'].isin(l_best_books)]
best_auth = best_auth.drop_duplicates(subset=['Book-Title'])

display(best_auth)


top_authors = best_auth['Book-Author'].value_counts().head(4)

print(top_authors)
# Out:
#        User-ID        ISBN  Book-Rating  \
# 1992    276788  043935806X            7
# 6574    276925  0316666343            0
# 7931    276925  0385504209            8
# 12721   276929  0439064864            0
# 13370   276939  059035342X            0
# 54431   277427  0439136369            0
# 54657   277427  043936213X            0
# 130656  278356  0439139600           10
#
#                                                Book-Title    Book-Author  \
# 1992    Harry Potter and the Order of the Phoenix (Boo...  J. K. Rowling
# 6574                            The Lovely Bones: A Novel   Alice Sebold
# 7931                                    The Da Vinci Code      Dan Brown
# 12721    Harry Potter and the Chamber of Secrets (Book 2)  J. K. Rowling
# 13370   Harry Potter and the Sorcerer's Stone (Harry P...  J. K. Rowling
# 54431   Harry Potter and the Prisoner of Azkaban (Book 3)  J. K. Rowling
# 54657      Harry Potter and the Sorcerer's Stone (Book 1)  J. K. Rowling
# 130656       Harry Potter and the Goblet of Fire (Book 4)  J. K. Rowling
#
#        Year-Of-Publication               Publisher  \
# 1992                  2003              Scholastic
# 6574                  2002           Little, Brown
# 7931                  2003               Doubleday
# 12721                 1999              Scholastic
# 13370                 1999  Arthur A. Levine Books
# 54431                 2001              Scholastic
# 54657                 2001              Scholastic
# 130656                2002   Scholastic Paperbacks
#
#                                               Image-URL-S  \
# 1992    http://images.amazon.com/images/P/043935806X.0...
# 6574    http://images.amazon.com/images/P/0316666343.0...
# 7931    http://images.amazon.com/images/P/0385504209.0...
# 12721   http://images.amazon.com/images/P/0439064864.0...
# 13370   http://images.amazon.com/images/P/059035342X.0...
# 54431   http://images.amazon.com/images/P/0439136369.0...
# 54657   http://images.amazon.com/images/P/043936213X.0...
# 130656  http://images.amazon.com/images/P/0439139600.0...
#
#                                               Image-URL-M  \
# 1992    http://images.amazon.com/images/P/043935806X.0...
# 6574    http://images.amazon.com/images/P/0316666343.0...
# 7931    http://images.amazon.com/images/P/0385504209.0...
# 12721   http://images.amazon.com/images/P/0439064864.0...
# 13370   http://images.amazon.com/images/P/059035342X.0...
# 54431   http://images.amazon.com/images/P/0439136369.0...
# 54657   http://images.amazon.com/images/P/043936213X.0...
# 130656  http://images.amazon.com/images/P/0439139600.0...
#
#                                               Image-URL-L
# 1992    http://images.amazon.com/images/P/043935806X.0...
# 6574    http://images.amazon.com/images/P/0316666343.0...
# 7931    http://images.amazon.com/images/P/0385504209.0...
# 12721   http://images.amazon.com/images/P/0439064864.0...
# 13370   http://images.amazon.com/images/P/059035342X.0...
# 54431   http://images.amazon.com/images/P/0439136369.0...
# 54657   http://images.amazon.com/images/P/043936213X.0...
# 130656  http://images.amazon.com/images/P/0439139600.0...
# J. K. Rowling    6
# Alice Sebold     1
# Dan Brown        1
# Name: Book-Author, dtype: int64

# %% [markdown]
# Using google books API
#
# https://www.googleapis.com/books/v1/volumes?q=search_term&key=AIzaSyCBCKiMTkSW3mjEVooUwMhxKet4_jGTvWk

# %%
import requests

url = 'https://www.googleapis.com/books/v1/volumes?q=search_term&key=AIzaSyCBCKiMTkSW3mjEVooUwMhxKet4_jGTvWk'

response = requests.get(url)

if response.status_code == 200:
    book_json = response.json()
    api_books = pd.json_normalize(book_json['items'])
    display(api_books)
else:
    print('Error:', response.status_code)
# Out:
#            kind            id         etag  \
# 0  books#volume  TA9QDwAAQBAJ  m4cSQ0u9zAc
# 1  books#volume  udlJEAAAQBAJ  ka8QxYQ4cFQ
# 2  books#volume  9AhnDwAAQBAJ  YdZSCy8ggcM
# 3  books#volume  m_F6cg6dkYQC  ExCvjDM7sJA
# 4  books#volume  fElmDwAAQBAJ  LbVJMmLHVWI
# 5  books#volume  PoeTAgAAQBAJ  q5OGlZUB+bo
# 6  books#volume  d9ebAgAAQBAJ  VfcTl6PMHpo
# 7  books#volume  hgwFAQAAQBAJ  zeQ7xtIO0n0
# 8  books#volume  2XliiK7FKoEC  ZX6tFx7bw7k
# 9  books#volume  x1w4EAAAQBAJ  VN9lBjMCYkI
#
#                                             selfLink  \
# 0  https://www.googleapis.com/books/v1/volumes/TA...
# 1  https://www.googleapis.com/books/v1/volumes/ud...
# 2  https://www.googleapis.com/books/v1/volumes/9A...
# 3  https://www.googleapis.com/books/v1/volumes/m_...
# 4  https://www.googleapis.com/books/v1/volumes/fE...
# 5  https://www.googleapis.com/books/v1/volumes/Po...
# 6  https://www.googleapis.com/books/v1/volumes/d9...
# 7  https://www.googleapis.com/books/v1/volumes/hg...
# 8  https://www.googleapis.com/books/v1/volumes/2X...
# 9  https://www.googleapis.com/books/v1/volumes/x1...
#
#                           volumeInfo.title  \
# 0  Rails, Angular, Postgres, and Bootstrap
# 1                         Job Ready Python
# 2                            Bash Cookbook
# 3                      Essential PHP Tools
# 4            The Site Reliability Workbook
# 5                    Raspberry Pi Projects
# 6                             PHP Cookbook
# 7         Raspberry Pi Hardware Projects 1
# 8                           Violent Python
# 9                           Rust in Action
#
#                                  volumeInfo.subtitle  \
# 0  Powerful, Effective, Efficient, Full-Stack Web...
# 1                                                NaN
# 2  Leverage Bash scripting to automate daily task...
# 3              Modules, Extensions, and Accelerators
# 4                    Practical Ways to Implement SRE
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  A Cookbook for Hackers, Forensic Analysts, Pen...
# 9                                                NaN
#
#                                   volumeInfo.authors    volumeInfo.publisher  \
# 0                                [David B. Copeland]     Pragmatic Bookshelf
# 1                 [Haythem Balti, Kimberly A. Weiss]       John Wiley & Sons
# 2                    [Ron Brash, Ganesh Sanjiv Naik]    Packt Publishing Ltd
# 3                                      [David Sklar]                  Apress
# 4  [Betsy Beyer, Niall Richard Murphy, David K. R...  "O'Reilly Media, Inc."
# 5                       [Andrew Robinson, Mike Cook]       John Wiley & Sons
# 6                   [David Sklar, Adam Trachtenberg]  "O'Reilly Media, Inc."
# 7                       [Andrew Robinson, Mike Cook]       John Wiley & Sons
# 8                                      [TJ O'Connor]                  Newnes
# 9                                     [Tim McNamara]      Simon and Schuster
#
#   volumeInfo.publishedDate                             volumeInfo.description  \
# 0               2017-06-22  Achieve awesome user experiences and performan...
# 1               2021-10-18  Get ready to take on Python with a practical a...
# 2               2018-07-31  Create simple to advanced shell scripts and en...
# 3               2008-01-01  * PHP is the leading programming language for ...
# 4               2018-07-25  In 2016, Google’s Site Reliability Engineering...
# 5               2014-01-10  Learn to build software and hardware projects ...
# 6               2006-08-25  Offers instructions for creating programs to d...
# 7               2013-09-25  Learn how to take full advantage of all of Ras...
# 8               2012-12-28  Violent Python shows you how to move from a th...
# 9               2021-08-10  Rust in Action introduces the Rust programming...
#
#    ... accessInfo.epub.isAvailable  accessInfo.pdf.isAvailable  \
# 0  ...                        True                        True
# 1  ...                        True                        True
# 2  ...                        True                        True
# 3  ...                       False                        True
# 4  ...                        True                        True
# 5  ...                        True                        True
# 6  ...                       False                        True
# 7  ...                        True                        True
# 8  ...                        True                        True
# 9  ...                       False                       False
#
#                             accessInfo.webReaderLink  \
# 0  http://play.google.com/books/reader?id=TA9QDwA...
# 1  http://play.google.com/books/reader?id=udlJEAA...
# 2  http://play.google.com/books/reader?id=9AhnDwA...
# 3  http://play.google.com/books/reader?id=m_F6cg6...
# 4  http://play.google.com/books/reader?id=fElmDwA...
# 5  http://play.google.com/books/reader?id=PoeTAgA...
# 6  http://play.google.com/books/reader?id=d9ebAgA...
# 7  http://play.google.com/books/reader?id=hgwFAQA...
# 8  http://play.google.com/books/reader?id=2XliiK7...
# 9  http://play.google.com/books/reader?id=x1w4EAA...
#
#    accessInfo.accessViewStatus accessInfo.quoteSharingAllowed  \
# 0                       SAMPLE                          False
# 1                       SAMPLE                          False
# 2                       SAMPLE                          False
# 3                       SAMPLE                          False
# 4                       SAMPLE                          False
# 5                       SAMPLE                          False
# 6                       SAMPLE                          False
# 7                       SAMPLE                          False
# 8                       SAMPLE                          False
# 9                       SAMPLE                          False
#
#                               searchInfo.textSnippet  \
# 0  ... attr_reader :where_clause, :where_args, :o...
# 1  LISTING 9.17 Searching a tuple # create a tupl...
# 2  Let&#39;s find all the files with the string &...
# 3  Listing 4-11. show-icecream-xml.tpl: XML Ice C...
# 4  <b>search_term</b>. to the click log to reduce...
# 5  Status() # has user passed command line argume...
# 6  The following code expects $_GET[&#39;<b>searc...
# 7  Chicken(pfio,0) # hasuserpassedcommandlineargu...
# 8  We will build our query function from the grou...
# 9  Listing 2.19 Manually incrementing an index va...
#
#                         accessInfo.epub.acsTokenLink  \
# 0                                                NaN
# 1  http://books.google.com.tw/books/download/Job_...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  http://books.google.com.tw/books/download/Rasp...
# 6                                                NaN
# 7  http://books.google.com.tw/books/download/Rasp...
# 8  http://books.google.com.tw/books/download/Viol...
# 9                                                NaN
#
#                          accessInfo.pdf.acsTokenLink volumeInfo.averageRating  \
# 0                                                NaN                      NaN
# 1  http://books.google.com.tw/books/download/Job_...                      NaN
# 2                                                NaN                      NaN
# 3  http://books.google.com.tw/books/download/Esse...                      NaN
# 4                                                NaN                      5.0
# 5  http://books.google.com.tw/books/download/Rasp...                      NaN
# 6                                                NaN                      NaN
# 7  http://books.google.com.tw/books/download/Rasp...                      NaN
# 8  http://books.google.com.tw/books/download/Viol...                      3.0
# 9                                                NaN                      NaN
#
#    volumeInfo.ratingsCount
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      1.0
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      1.0
# 9                      NaN
#
# [10 rows x 51 columns]
